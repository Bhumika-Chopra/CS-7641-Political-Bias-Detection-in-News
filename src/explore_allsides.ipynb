# %%
from datasets import load_dataset

dataset = load_dataset("lelouch0204/cleaned_allsides_v2")

df = dataset["train"].to_pandas()

display(df.head(20))
# Out:
# Generating train split: 100%|██████████| 6209/6209 [00:00<00:00, 8899.62 examples/s]
#                                                 Title  \
# 0   As Trump throws immigration into uncertainty, ...
# 1   RFK Jr. reports up to $1.2M in credit card deb...
# 2   Trump moves to brand Houthis as a foreign terr...
# 3   Sen. John Fetterman on flurry of Trump executi...
# 4   Heads of Oath Keepers, Proud Boys released fro...
# 5   Lightning-rod immigration bill set to go to Tr...
# 6   DC judges slam Trump Jan. 6 pardons as 'revisi...
# 7    How Trump might change the world in his 2nd term
# 8   Trump's pardons for rioters 'disturbing,' form...
# 9   Bidenâ€™s letter to Trump wished him 'all the ...
# 10  Trump's record-breaking executive actions prom...
# 11  Trump criticizes sermon asking him to show 'me...
# 12  Trump demands Putin â€˜make a dealâ€™ now to e...
# 13  Trump authorizes ICE to target courthouses, sc...
# 14  Conflicting accounts on congressional Republic...
# 15  White House orders removal of Mark Milley port...
# 16  Trump order leaves Afghans who were approved t...
# 17  Rubio reveals three questions that will determ...
# 18  Bolton slams Trump after Secret Service detail...
# 19  With the stroke of the pen, Trump tries to rem...
#
#                                                  Link  \
# 0   https://abcnews.go.com/Politics/trump-throws-i...
# 1   https://abcnews.go.com/Politics/rfk-jr-reports...
# 2   https://abcnews.go.com/Politics/trump-moves-br...
# 3   https://abcnews.go.com/Politics/sen-john-fette...
# 4   https://abcnews.go.com/Politics/oath-keepers-p...
# 5   https://abcnews.go.com/Politics/house-vote-lak...
# 6   https://abcnews.go.com/Politics/dc-judges-slam...
# 7   https://abcnews.go.com/Politics/trump-wield-am...
# 8   https://abcnews.go.com/Politics/trumps-pardons...
# 9   https://abcnews.go.com/Politics/trump-calls-bi...
# 10  https://abcnews.go.com/Politics/trumps-record-...
# 11  https://abcnews.go.com/Politics/trump-criticiz...
# 12  https://abcnews.go.com/Politics/trump-demands-...
# 13  https://abcnews.go.com/Politics/trump-authoriz...
# 14  https://abcnews.go.com/Politics/conflicting-ac...
# 15  https://abcnews.go.com/Politics/mark-milleys-p...
# 16  https://abcnews.go.com/Politics/trump-order-le...
# 17  https://abcnews.go.com/Politics/marco-rubio-sw...
# 18  https://abcnews.go.com/Politics/john-bolton-tr...
# 19  https://abcnews.go.com/Politics/stroke-pen-tru...
#
#                                                  Text   Source       Bias  \
# 0   As President Donald Trump starts to defend his...  abcnews  lean left
# 1   From a multimillion-dollar law firm payout to ...  abcnews  lean left
# 2   President Donald Trump issued an executive ord...  abcnews  lean left
# 3   President Donald Trump launched his plan to re...  abcnews  lean left
# 4   Enrique Tarrio, the former head of the Proud B...  abcnews  lean left
# 5   The House passed an amended version of the Lak...  abcnews  lean left
# 6   In the days since President Donald Trump hande...  abcnews  lean left
# 7   Donald Trump returned to office as president o...  abcnews  lean left
# 8   President Donald Trump's sweeping pardons and ...  abcnews  lean left
# 9   Former President Joe Biden wished President Do...  abcnews  lean left
# 10  Armed with plenty of black Sharpies, President...  abcnews  lean left
# 11  Following a traditional inaugural prayer servi...  abcnews  lean left
# 12  President Donald Trump on Wednesday sent a mes...  abcnews  lean left
# 13  Federal immigration authorities will be permit...  abcnews  lean left
# 14  President Donald Trump and Vice President JD V...  abcnews  lean left
# 15  The White House ordered that retired Gen. Mark...  abcnews  lean left
# 16  President Donald Trump's executive order freez...  abcnews  lean left
# 17  After taking the oath of office to be sworn in...  abcnews  lean left
# 18  President Donald Trump has terminated Secret S...  abcnews  lean left
# 19  With half the country firmly behind him and wi...  abcnews  lean left
#
#     text_length                                         clean_text  \
# 0          5179  as president donald trump starts to defend his...
# 1          5260  from a multimillion dollar law firm payout to ...
# 2          5151  president donald trump issued an executive ord...
# 3          6384  president donald trump launched his plan to re...
# 4          3939  enrique tarrio the former head of the proud bo...
# 5          6033  the house passed an amended version of the lak...
# 6          5123  in the days since president donald trump hande...
# 7          4797  donald trump returned to office as president o...
# 8          7295  president donald trump sweeping pardons and co...
# 9          2022  former president joe biden wished president do...
# 10        12164  armed with plenty of black sharpies president ...
# 11         3698  following a traditional inaugural prayer servi...
# 12         1534  president donald trump on wednesday sent a mes...
# 13         3388  federal immigration authorities will be permit...
# 14         4167  president donald trump and vice president jd v...
# 15         4125  the white house ordered that retired gen mark ...
# 16         2652  president donald trump executive order freezin...
# 17         4225  after taking the oath of office to be sworn in...
# 18         1775  president donald trump has terminated secret s...
# 19         5282  with half the country firmly behind him and wi...
#
#                                            lemmatized  \
# 0   president donald trump start defend executive ...
# 1   multimillion dollar law firm payout figure end...
# 2   president donald trump issue executive order i...
# 3   president donald trump launch plan reshape ame...
# 4   enrique tarrio head proud boy stewart rhode he...
# 5   house pass amend version laken riley act wedne...
# 6   day president donald trump hand pardon commuta...
# 7   donald trump return office president monday re...
# 8   president donald trump sweeping pardon commuta...
# 9   president joe biden wish president donald trum...
# 10  arm plenty black sharpie president donald trum...
# 11  follow traditional inaugural prayer service wa...
# 12  president donald trump wednesday send message ...
# 13  federal immigration authority permit target sc...
# 14  president donald trump vice president vance br...
# 15  white house order retired gen mark milley offi...
# 16  president donald trump executive order freeze ...
# 17  take oath office swear nation secretary state ...
# 18  president donald trump terminate secret servic...
# 19  half country firmly blessing america tech bill...
#
#                                              keywords  cluster  \
# 0   [child, lawsuit, citizenship, monica, states, ...        2
# 1   [kennedy, disclosure, million, liability, earn...        1
# 2   [houthis, designation, group, yemen, terrorist...        1
# 3   [fetterman, abc, agree, pardon, news, lago, lo...        2
# 4   [rhode, keeper, capitol, oath, violent, convic...        2
# 5   [bill, vote, senate, riley, immigration, pass,...        3
# 6   [judge, capitol, dismissal, officer, occur, pa...        2
# 7   [hamas, israel, ukraine, america, peace, trump...        4
# 8   [pardon, rioter, enforcement, officer, law, at...        2
# 9   [letter, trump, biden, oval, leave, office, pr...        2
# 10  [executive, order, trump, action, say, gulf, s...        2
# 11  [budde, mercy, sermon, trump, church, bishop, ...        2
# 12  [putin, deal, trump, indicate, russia, zelensk...        4
# 13  [ice, courthouse, memo, enforcement, immigrati...        3
# 14  [thune, johnson, meeting, republicans, lot, st...        1
# 15  [milley, portrait, pardon, hang, staff, pentag...        2
# 16  [afghanistan, refugee, abc, afghan, order, gra...        1
# 17  [rubio, ukraine, state, russia, conflict, span...        4
# 18  [bolton, classified, book, security, adviser, ...        2
# 19  [trump, firmly, congress, executive, say, pres...        2
#
#     __index_level_0__
# 0                   1
# 1                   4
# 2                   5
# 3                   7
# 4                   9
# 5                  10
# 6                  11
# 7                  13
# 8                  14
# 9                  15
# 10                 17
# 11                 18
# 12                 19
# 13                 20
# 14                 27
# 15                 29
# 16                 32
# 17                 35
# 18                 36
# 19                 37

# %%
print(df["Bias"].value_counts())
# Out:
# Bias
# left          2967
# right         1273
# lean left      776
# center         644
# lean right     549
# Name: count, dtype: int64

# %%
LABEL2ID = {
    "left": 1,
    "lean left": 2,
    "center": 3,
    "lean right": 4,
    "right": 5
}

# %%
import json
import pandas as pd
import random
from tqdm import tqdm
import os
from itertools import combinations

def build_ordinal_simcse_pairs(df, output_path, 
                               max_pos_per_label=3000, 
                               max_neg_per_label=6000):
    """
    Build ordinal supervised SimCSE training pairs from a DataFrame
    with 'cleaned_text' and 'label' columns.
    
    Args:
        df: pandas DataFrame with 'cleaned_text' and 'label'
        output_path: path to save JSON
        max_pos_per_label: max positive pairs per label
        max_neg_per_label: max negative pairs per label
    """
    os.makedirs(os.path.dirname(output_path), exist_ok=True)

    # Convert labels to numeric 1–5
    df["id_label"] = df["Bias"].map(LABEL2ID)
    print(f"ID Label dist: {df['id_label'].value_counts().to_dict()}")

    # Group texts by label
    groups = {i: df[df["id_label"] == i]["clean_text"].tolist() 
              for i in LABEL2ID.values()}

    # Remove empty groups
    groups = {k: v for k, v in groups.items() if len(v) > 0}
    valid_labels = list(groups.keys())

    pairs = []
    print(f"Valid labels: {valid_labels}")

    # -----------------------------
    # Positive pairs
    # -----------------------------
    print("Building positive pairs...")
    for label, texts in groups.items():
        n_texts = len(texts)
        if n_texts < 2:
            continue  # skip too small classes

        # If class is small, take all combinations
        if n_texts < 50:
            for s1, s2 in combinations(texts, 2):
                pairs.append({
                    "sentence1": s1,
                    "sentence2": s2,
                    "label1": label,
                    "label2": label
                })
        else:
            # Otherwise, randomly sample up to max_pos_per_label
            for _ in range(max_pos_per_label):
                s1, s2 = random.sample(texts, 2)
                pairs.append({
                    "sentence1": s1,
                    "sentence2": s2,
                    "label1": label,
                    "label2": label
                })

    # -----------------------------
    # Negative pairs
    # -----------------------------
    print("Building negative pairs...")
    for label1, texts1 in tqdm(groups.items()):
        n_texts1 = len(texts1)
        if n_texts1 == 0:
            continue

        # Sample up to max_neg_per_label per label
        for _ in range(min(max_neg_per_label, n_texts1)):
            s1 = random.choice(texts1)

            # Pick a different non-empty label
            other_labels = [l for l in valid_labels if l != label1 and len(groups[l]) > 0]
            if not other_labels:
                continue
            label2 = random.choice(other_labels)
            s2 = random.choice(groups[label2])

            pairs.append({
                "sentence1": s1,
                "sentence2": s2,
                "label1": label1,
                "label2": label2
            })

    # Shuffle final dataset
    random.shuffle(pairs)
    print(f"Total training pairs: {len(pairs)}")

    # Save to JSON
    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(pairs, f, indent=2)

    print(f"Saved to {output_path}")

# %%
build_ordinal_simcse_pairs(df=df, 
                           output_path="./data/allsides/ordinal_simcse_pairs.json")
# Out:
# ID Label dist: {1: 2967, 5: 1273, 2: 776, 3: 644, 4: 549}
# Valid labels: [1, 2, 3, 4, 5]
# Building positive pairs...
# Building negative pairs...
# 100%|██████████| 5/5 [00:00<00:00, 429.21it/s]
# Total training pairs: 21209
# Saved to ./data/allsides/ordinal_simcse_pairs.json

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# -----------------------------
# Load your existing PKL files
# -----------------------------
train_df = pd.read_pickle("./data/allsides/dataset_train_split.pkl")
test_df = pd.read_pickle("./data/allsides/dataset_test_split.pkl")

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)

# Inspect columns
print(train_df.columns)
# Out:
# Train shape: (4967, 11)
# Test shape: (1242, 11)
# Index(['Title', 'Link', 'Text', 'Source', 'Bias', 'text_length', 'clean_text',
#        'lemmatized', 'keywords', 'cluster', '__index_level_0__'],
#       dtype='object')

# %%
label_col = "Bias"   # change if needed
text_col = "clean_text"  # or whatever your column is

# %%
embed_train_df, classifier_train_df = train_test_split(
    train_df,
    test_size=0.20,
    random_state=42,
    stratify=train_df[label_col]   # keeps class distribution!!!
)

print("Embedding Train:", embed_train_df.shape)
print("Classifier Train:", classifier_train_df.shape)
print("Test:", test_df.shape)

embed_train_df[label_col].value_counts(normalize=True).round(3)
# Out:
# Embedding Train: (3973, 11)
# Classifier Train: (994, 11)
# Test: (1242, 11)
# Bias
# left          0.478
# right         0.205
# lean left     0.125
# center        0.104
# lean right    0.088
# Name: proportion, dtype: float64

# %%
embed_train_df.to_pickle("./data/allsides/embed_train.pkl")
classifier_train_df.to_pickle("./data/allsides/classifier_train.pkl")

# %%
build_ordinal_simcse_pairs(df=embed_train_df, 
                           output_path="./data/allsides/ordinal_simcse_pairs_embed.json")
# Out:
# ID Label dist: {1: 1899, 5: 814, 2: 497, 3: 412, 4: 351}
# Valid labels: [1, 2, 3, 4, 5]
# Building positive pairs...
# Building negative pairs...
# 100%|██████████| 5/5 [00:00<00:00, 429.57it/s]
# Total training pairs: 18973
# Saved to ./data/allsides/ordinal_simcse_pairs_embed.json
